# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# Out:
# fatal: destination path 'yolov9' already exists and is not an empty directory.

# %%
# !pip install -r yolov9/requirements.txt -q

# %%
cd yolov9
# Out:
# /content/yolov9

# %%
import os

HOME = os.getcwd()
print(HOME)
# Out:
# /content/yolov9

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key = 'Y3igGobQiqpQKsPQGlag')
project = rf.workspace('jeongwan-ryu-n5zsh').project('deep_learning_project_neglect')
version = project.version(4)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Deep_Learning_Project_Neglect-4 in yolov9:: 100%|██████████| 1726/1726 [00:00<00:00, 5931.54it/s]

# %%
versions = project.versions()
for version in versions:
    print(f"Version id: {version.id}, Version: {version.version}")
# Out:
# Version id: jeongwan-ryu-n5zsh/deep_learning_project_neglect/4, Version: 4
# Version id: jeongwan-ryu-n5zsh/deep_learning_project_neglect/3, Version: 3
# Version id: jeongwan-ryu-n5zsh/deep_learning_project_neglect/2, Version: 2
# Version id: jeongwan-ryu-n5zsh/deep_learning_project_neglect/1, Version: 1

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.6/862.6 kB 29.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov9c.yaml")

# %%
model = YOLO("yolov9c.pt")
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 381MB/s]

# %%
model.train(data = '/content/yolov9/Deep_Learning_Project_Neglect-4/data.yaml', epochs = 10, imgsz = 320)
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...
