# %%
import pandas as pd

# %%
dp=pd.read_csv('C:/Users/M/Desktop/파일정리진행본_0621/데이터/전동킥보드/서울시 전동킥보드 견인 현황1 (1).csv',encoding='cp949')
#dp=dp.sort_values('count',ascending=False)
dp.value_counts('구정보')
# Out:
# 구정보
# 마포구     12588
# 송파구     12234
# 성동구     11163
# 강남구     10802
# 영등포구    10257
# 서초구      8965
# 동작구      7128
# 관악구      6632
# 용산구      5766
# 동대문구     5408
# 강서구      5392
# 광진구      4174
# 중랑구      3846
# 강동구      3640
# 노원구      3404
# 도봉구      3287
# 서대문구     2863
# 중구       2663
# 종로구      2148
# 강북구      2098
# 성북구      2073
# 구로구      1628
# 양천구      1376
# 은평구       387
# 금천구        10
# Name: count, dtype: int64

# %%
counts = dp.value_counts('구정보')

# %%
counts_df = counts.reset_index()
counts_df['비율'] = counts_df['count'] / counts_df['count'].sum()

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus']= False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)


plt.pie(counts_df['count'], labels=counts_df['구정보'], autopct='%1.1f%%')
plt.title('견인')
plt.show()

# %%
pk=pd.read_csv('C:/Users/M/Desktop/파일정리진행본_0621/데이터/전동킥보드/서울시 전동킥보드 주차구역 현황1 (1).csv',encoding='cp949')

# %%
pk.value_counts('시군구명')
# Out:
# 시군구명
# 서초구     49
# 강서구     21
# 종로구     17
# 동대문구    14
# 강남구     10
# 마포구     10
# 강북구      9
# 송파구      7
# 관악구      6
# 용산구      5
# 금천구      5
# 강동구      5
# 양천구      4
# 성북구      4
# 동작구      4
# 도봉구      4
# 노원구      4
# 중구       4
# 구로구      3
# 은평구      2
# 성동구      1
# 서대문구     1
# 광진구      1
# Name: count, dtype: int64

# %%
counts = pk.value_counts('시군구명')

# %%
counts_df = counts.reset_index()
counts_df['비율'] = counts_df['count'] / counts_df['count'].sum()

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus']= False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)


plt.pie(counts_df['count'], labels=counts_df['시군구명'], autopct='%1.1f%%')
plt.title('시군구별 주차장 개수')
plt.show()

# %%
# #선정기준 이용률 , 견인건수가 높고 

# 주차구역이 현황비율이 낮은 곳 3개구 5개소 씩

# 강남구

# 송파구 

# 마포구
